# %%
import pandas as pd
import numpy as np
import os

# %%
a = None
b = 'test'

# %%
if not a:
    print('test')
# Out:
# test

# %%
if b:
    print('test')
# Out:
# test

# %%
urls = pd.read_csv('/mnt/storage/labs/mitchell/projects/matchup-workflow-data/publish-dev-data/temp/05-download-urls.csv', names=['granid','granurl','wlon','slat','elon','nlat'])

# %%
num_urls = len(urls)

# %%
unique_sats = np.unique([gid[0:-13] for gid in urls['granid']])

# %%
unique_sats
# Out:
# array(['A', 'T', 'V1J', 'VS'], dtype='<U3')

# %%
satdir_files = os.listdir('/mnt/storage/labs/mitchell/projects/matchup-workflow-data/publish-dev-data/temp/satellite-files')

# %%
satdir_files
# Out:
# ['aqua', 'terra', 'snpp', 'jpss1', 'jpss2']

# %%
l2_files = []
for root, dirs, files in os.walk('/mnt/storage/labs/mitchell/projects/matchup-workflow-data/publish-dev-data/temp/satellite-files/'):
    for file in files:
        if file.endswith('.L2'):
            l2_files.append(file)

# %%
l2_files
# Out:
# ['A2002233174000.L2',
#  'A2004286150500.L2',
#  'A2005178035500.L2',
#  'A2005178132500.L2',
#  'A2005201165000.L2',
#  'A2008355185000.L2',
#  'A2008355171500.L2',
#  'A2008356175500.L2',
#  'A2010141175500.L2',
#  'A2010290145500.L2',
#  'A2010299162000.L2',
#  'A2010302151000.L2',
#  'A2010305154000.L2',
#  'A2011033163000.L2',
#  'A2011176010000.L2',
#  'A2011283155000.L2',
#  'A2018189183000.L2',
#  'A2018189165000.L2',
#  'A2020027122000.L2',
#  'A2020049114500.L2',
#  'A2021031003500.L2',
#  'A2021030225500.L2',
#  'T2002233160000.L2',
#  'T2005178114500.L2',
#  'T2005201151000.L2',
#  'T2010141161000.L2',
#  'T2010290131000.L2',
#  'T2010290113500.L2',
#  'T2010299131000.L2',
#  'T2010305124000.L2',
#  'T2011033105000.L2',
#  'T2011033122500.L2',
#  'T2011283124000.L2',
#  'T2018189151500.L2',
#  'T2020049073500.L2',
#  'T2021030185000.L2',
#  'VS2018189163001.L2',
#  'VS2018189181200.L2',
#  'VS2020027115401.L2',
#  'VS2020049114201.L2',
#  'VS2021030231800.L2',
# ...

# %%
import os
for root, dirs, files in os.walk('/mnt/storage/labs/mitchell/projects/matchup-workflow-data/publish-dev-data/temp/satellite-files'):
    for file in files:
        if file.endswith(".txt"):
             print(os.path.join(root, file))

# %%
#df = pd.read_csv('/mnt/storage/labs/mitchell/projects/pic-algorithm/2022-analysis/srp-workflow/02b-matchup-dataframe-configuration/04-matchup-df-formatted.csv')
field = pd.read_csv('/mnt/storage/labs/mitchell/projects/pic-algorithm/2022-analysis/srp-workflow/01-field-data-configuration/05-field-data.csv')
# Out:
# /home/spinkham/sunnysenv/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (2,3,10) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
ids = ['tn376_171699','amt21_45542','tn376_175572','s981013w_104813','amt20_37999',
       's020821w_116768','s100521e_143914','s050720e_127018','s020821w_116701','amt20_39341',
       'rr2004_182934','copas08_59451','amt15_3809','en616_166812','tan1109_189527',
       'amt20_36189','mv1101_78988','amt16_12663','amt20_38684','copas08_59179']
pic_sample = field.loc[field.ID.isin(ids)]

# %%
pic_sample.to_csv('/mnt/storage/labs/mitchell/projects/matchup-workflow-data/publish-dev-data/temp/01-pic-sample-field.csv', index=False)

# %%
string='a25_viirs'

# %%
'viirs' not in string
# Out:
# False

# %%
fp = '/mnt/storage/labs/mitchell/projects/matchup-workflow-data/publish-dev-data/temp/amt-l1a-bounding-box-expansion-test-file.csv'

# %%
df_l1a = pd.read_csv(fp, names=['station','granid','granurl','wlon','slat','elon','nlat'])

# %%
curr_df = df_l1a.loc[df_l1a['station']=='amt16_6688']

# %%
curr_df.loc[curr_df['granid'].str[0]=='A']
# Out:
#       station          granid  \
# 0  amt16_6688  A2005147135000
# 1  amt16_6688  A2005147134500
# 2  amt16_6688  A2005147135001
#
#                                              granurl    wlon       slat  \
# 0  https://oceandata.sci.gsfc.nasa.gov/cmr/getfil... -6.1586 -29.856083
# 1  https://oceandata.sci.gsfc.nasa.gov/cmr/getfil... -6.1586 -29.856083
# 2  https://oceandata.sci.gsfc.nasa.gov/cmr/getfil... -6.1586 -29.856083
#
#      elon       nlat
# 0 -4.1586 -27.856083
# 1 -4.1586 -27.856083
# 2 -4.1586 -27.856083

# %%
urls = []
wlons = []
elons = []
slats = []
nlats = []

for url in df_l1a['granurl'].unique():
    curr_df = df_l1a.loc[df_l1a['granurl']==url]
    urls.append(url)
    wlons.append(curr_df['wlon'].min())
    elons.append(curr_df['elon'].max())
    slats.append(curr_df['slat'].min())
    nlats.append(curr_df['nlat'].max())

#download_l1as = pd.DataFrame(data=[urls,wlons,slats,elons,nlats], columns=['granurl','wlon','slat','elon','nlat'])
#download_l1as.to_csv(dict_args['ofile'][0], index=False, header=False)

# %%
data=[urls,wlons,slats,elons,nlats]

# %%
pd.DataFrame({'granurl':urls,'wlon':wlons,'slat':slats,'elon':elons,'nlat':nlats})
# Out:
#                                               granurl       wlon       slat  \
# 0   https://oceandata.sci.gsfc.nasa.gov/cmr/getfil...  -8.445250 -29.856083
# 1   https://oceandata.sci.gsfc.nasa.gov/cmr/getfil...  -8.419383 -29.856083
# 2   https://oceandata.sci.gsfc.nasa.gov/cmr/getfil...  -8.445250 -29.856083
# 3   https://oceandata.sci.gsfc.nasa.gov/cmr/getfil...  -8.775933 -29.660717
# 4   https://oceandata.sci.gsfc.nasa.gov/cmr/getfil... -13.034300 -28.980583
# 5   https://oceandata.sci.gsfc.nasa.gov/cmr/getfil... -13.034300 -28.980583
# 6   https://oceandata.sci.gsfc.nasa.gov/cmr/getfil... -16.743833 -28.213333
# 7   https://oceandata.sci.gsfc.nasa.gov/cmr/getfil... -16.743833 -28.213333
# 8   https://oceandata.sci.gsfc.nasa.gov/cmr/getfil... -21.011933 -27.425133
# 9   https://oceandata.sci.gsfc.nasa.gov/cmr/getfil... -21.011933 -27.425133
# 10  https://oceandata.sci.gsfc.nasa.gov/cmr/getfil... -25.136033 -26.491583
# ...

# %%
pd.DataFrame(data=[urls,wlons,slats,elons,nlats], columns=['granurl','wlon','slat','elon','nlat'])
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# ~/sunnysenv/lib/python3.9/site-packages/pandas/core/internals/construction.py in _finalize_columns_and_data(content, columns, dtype)
#     905     try:
# --> 906         columns = _validate_or_indexify_columns(contents, columns)
#     907     except AssertionError as err:
#
# ~/sunnysenv/lib/python3.9/site-packages/pandas/core/internals/construction.py in _validate_or_indexify_columns(content, columns)
#     953             # caller's responsibility to check for this...
# --> 954             raise AssertionError(
#     955                 f"{len(columns)} columns passed, passed data had "
#
# AssertionError: 5 columns passed, passed data had 21 columns
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# ...

# %%
pd.read_csv?
# Out:
# Signature:
# pd.read_csv(
#     filepath_or_buffer: 'FilePathOrBuffer',
#     sep=<no_default>,
#     delimiter=None,
#     header='infer',
#     names=<no_default>,
#     index_col=None,
#     usecols=None,
#     squeeze=False,
#     prefix=<no_default>,
#     mangle_dupe_cols=True,
#     dtype: 'DtypeArg | None' = None,
#     engine=None,
#     converters=None,
#     true_values=None,
#     false_values=None,
#     skipinitialspace=False,
#     skiprows=None,
#     skipfooter=0,
#     nrows=None,
#     na_values=None,
#     keep_default_na=True,
#     na_filter=True,
#     verbose=False,
#     skip_blank_lines=True,
#     parse_dates=False,
#     infer_datetime_format=False,
#     keep_date_col=False,
#     date_parser=None,
#     dayfirst=False,
#     cache_dates=True,
#     iterator=False,
#     chunksize=None,
#     compression='infer',
#     thousands=None,
#     decimal: 'str' = '.',
#     lineterminator=None,
#     quotechar='"',
#     quoting=0,
#     doublequote=True,
# ...

# %%
field = pd.read_csv('/mnt/storage/labs/mitchell/projects/matchup-workflow-data/publish-dev-data/01-field-data.csv')

# %%
field.head()
# Out:
#    MatchupID CruiseName StationTime  yyyy-mm-ddThh:mm:ss  Longitude  Latitude  \
# 0          0   s980917w         NaN  1998-09-17 13:46:48        NaN       NaN
# 1          1   s980917w         NaN  1998-09-17 13:47:13        NaN       NaN
# 2          2   s980917w         NaN  1998-09-17 13:47:35        NaN       NaN
# 3          3   s980917w         NaN  1998-09-17 13:47:56        NaN       NaN
# 4          4   s980917w         NaN  1998-09-17 13:48:18        NaN       NaN
#
#    StationDataID  StationInfoID  Depth  Shallowest  ...  cgp715  cg412  cg440  \
# 0            NaN            NaN    NaN         NaN  ...     NaN    NaN    NaN
# 1            NaN            NaN    NaN         NaN  ...     NaN    NaN    NaN
# 2            NaN            NaN    NaN         NaN  ...     NaN    NaN    NaN
# 3            NaN            NaN    NaN         NaN  ...     NaN    NaN    NaN
# 4            NaN            NaN    NaN         NaN  ...     NaN    NaN    NaN
#
# ...

# %%
pd.DataFrame?
# Out:
# Init signature:
# pd.DataFrame(
#     data=None,
#     index: 'Axes | None' = None,
#     columns: 'Axes | None' = None,
#     dtype: 'Dtype | None' = None,
#     copy: 'bool | None' = None,
# )
# Docstring:
# Two-dimensional, size-mutable, potentially heterogeneous tabular data.
#
# Data structure also contains labeled axes (rows and columns).
# Arithmetic operations align on both row and column labels. Can be
# thought of as a dict-like container for Series objects. The primary
# pandas data structure.
#
# Parameters
# ----------
# data : ndarray (structured or homogeneous), Iterable, dict, or DataFrame
#     Dict can contain Series, arrays, constants, dataclass or list-like objects. If
#     data is a dict, column order follows insertion-order.
#
#     .. versionchanged:: 0.25.0
#        If data is a list of dicts, column order follows insertion-order.
#
# index : Index or array-like
#     Index to use for resulting frame. Will default to RangeIndex if
# ...

# %%
field.UWid[field.UWid.isnull()==True]
# Out:
# 2756    NaN
# 4065    NaN
# 4066    NaN
# 4067    NaN
# 4068    NaN
# 4069    NaN
# 4070    NaN
# 4071    NaN
# 4072    NaN
# 4073    NaN
# 4227    NaN
# 7092    NaN
# 18732   NaN
# 26827   NaN
# 28623   NaN
# 40045   NaN
# 40046   NaN
# 40061   NaN
# 40114   NaN
# 40272   NaN
# 40372   NaN
# 42444   NaN
# 42581   NaN
# 43239   NaN
# 44806   NaN
# 50706   NaN
# 51687   NaN
# 51688   NaN
# 51850   NaN
# 51935   NaN
# 51936   NaN
# 52249   NaN
# 52250   NaN
# 53495   NaN
# 56897   NaN
# 56898   NaN
# 56899   NaN
# 56900   NaN
# 56905   NaN
# 56955   NaN
# 56971   NaN
# Name: UWid, dtype: float64

# %%
abs(a)>180
# Out:
# False
